# %% [markdown]
# ## List of Strings

# %%
book_types = [
    'Classics', 'Tragedy', 'Sci-fi', 'Fantancy', 'Action', 
    'Crime', 'Humor', 'Horror', 'Comics', 'Biography'
    ]

# %%
print(book_types)
# Out:
# ['Classics', 'Tragedy', 'Sci-fi', 'Fantancy', 'Action', 'Crime', 'Humor', 'Horror', 'Comics', 'Biography']

# %% [markdown]
# ## List with Duplicates

# %%
book_name = ['cinder', 'winter', 'lore', 'cinder']
print(len(book_name))
# Out:
# 4

# %% [markdown]
# ## Lists are Mutable

# %%
book_name = ['cinder', 'winter', 'lore', 'cinder']
print("Before Changing : ", book_name)

book_name = ['cinder', 'winter']
print("After Changing : ",book_name)
# Out:
# Before Changing :  ['cinder', 'winter', 'lore', 'cinder']
# After Changing :  ['cinder', 'winter']

# %% [markdown]
# # Exercise 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
book_id = [101, 102, 103, 104, 105, 106, 107, 108, 109, 110]

# %% [markdown]
# ## List of Multiple Data Types

# %%
book = [1,['cinder', 345.89], 'crime', ('lore') ]

# %% [markdown]
# ## List of Lists

# %%
book_types=[['Classics',101.1],['Tragedy',102],['Sci-fi',103]]

# %% [markdown]
# ## List of Tuples

# %%
book_types=[('Classics',101.1),('Tragedy',102),('Sci-fi',103)]

# %% [markdown]
# ## List of Dictionaries

# %%
book_types=[{'Classics',101.1},{'Tragedy',102},{'Sci-fi',103}]

# %% [markdown]
# # Exercise 2

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Columns as Lists

# %%
sno = [1,2,3,4]
name = ['anu','alice','ken','bob']
age = [29, 52,48,25]
score = [500.25, 428.8, 562, 897.09]
languages = [('Python','Java'),('C', 'C++'),('Go'),('HTML', 'CSS')]

# %% [markdown]
# # Store Column by Column

# %%
student = [sno, name, age, score, languages]
print(student)
# Out:
# [[1, 2, 3, 4], ['anu', 'alice', 'ken', 'bob'], [29, 52, 48, 25], [500.25, 428.8, 562, 897.09], [('Python', 'Java'), ('C', 'C++'), 'Go', ('HTML', 'CSS')]]

# %% [markdown]
# # Store Row by Row

# %%
student = [(1,'anu',29,500.29,('Python','Java')),
          (2,'alice',52,428.8,('C','C++')),
            (3,'ken',48,562,('Go')),
               (4,'bob',25,897.09,('HTML','CSS'))           
          ]
print(student)
# Out:
# [(1, 'anu', 29, 500.29, ('Python', 'Java')), (2, 'alice', 52, 428.8, ('C', 'C++')), (3, 'ken', 48, 562, 'Go'), (4, 'bob', 25, 897.09, ('HTML', 'CSS'))]

# %% [markdown]
# # Store Row by Row - Better Option

# %%
student = list(zip(sno, name, age, score, languages))
print(student)
# Out:
# [(1, 'anu', 29, 500.25, ('Python', 'Java')), (2, 'alice', 52, 428.8, ('C', 'C++')), (3, 'ken', 48, 562, 'Go'), (4, 'bob', 25, 897.09, ('HTML', 'CSS'))]
